# %%
import json as j # for parsing text in json before loading into dataframe 
import pandas as pd # for creating and manipulating the dataframes
from pandas.io.json import json_normalize #package for flattening json in pandas df

import re # REGEX for text
from nltk.corpus import stopwords # for removal of stop words
from nltk.stem import SnowballStemmer # for word stemming

from nltk import word_tokenize # for tokenization of words
from nltk.util import ngrams # for generating unigrams, bigrams, trigrams
import numpy as np # for working with matrices 
import matplotlib.pyplot as plt # for charting

from sklearn.pipeline import Pipeline # for creating an analysis pipeline
from sklearn.model_selection import train_test_split # for splitting dataset into training and testing
from sklearn.feature_extraction.text import TfidfVectorizer # for TF-IDF
from sklearn.cluster import KMeans #for generating document clusters
from sklearn.metrics import adjusted_rand_score #for generating random index
from sklearn.metrics import precision_recall_fscore_support #for evaluating model
from sklearn.svm import LinearSVC # for generating model
from sklearn.naive_bayes import MultinomialNB # for generating model
from sklearn.ensemble import RandomForestClassifier # for generating model

# %% [markdown]
# # Step 1: Parse and Load

# %%
#load first json object
with open('D:/CAPSTONE_NEW/indeed_com-jobs_us_deduped_n_merged_20170817_113447896253141.json', encoding="utf-8-sig") as data_file:
    json_data1 = j.load(data_file)

# %%
#put data file 1 into a pandas df
#parent node is 'page'
#print first 5 rows
jobs_data1 = json_normalize(json_data1['page'])
jobs_data1.head(5)
# Out:
#                                              pageurl  \
# 0  http://www.indeed.com/cmp/Tileland-Interior-De...
# 1  http://www.indeed.com/viewjob?jk=c5d36d1df92067d8
# 2  http://www.indeed.com/viewjob?jk=eb4d64f6aee216f0
# 3  http://www.indeed.com/viewjob?jk=b0b80ca728afedee
# 4  http://www.indeed.com/viewjob?jk=50d5a5844e56e24b
#
#            record.company_name  \
# 0  Tileland Interior Decor LLC
# 1                 ASRC Federal
# 2  MSLA, A Medical Corporation
# 3  TriWest Healthcare Alliance
# 4                         Tyco
#
#                                   record.description  \
# 0  Office assistantResponsibilities include: Prep...
# 1  Financial Investigators - Asset Forfeiture -El...
# 2  Employment Summary\nSummary of Job Function an...
# 3  Profile\n\n\nJob Summary\n\n\nSupervises, trai...
# 4  Position Summary:\nThe National Account Field ...
#
#             record.direct_apply_link_on_the_job_page  \
# 0                                                NaN
# 1  http://www.indeed.com/rc/clk?jk=c5d36d1df92067...
# 2  http://www.indeed.com/rc/clk?jk=eb4d64f6aee216...
# 3  http://www.indeed.com/rc/clk?jk=b0b80ca728afed...
# 4  http://www.indeed.com/rc/clk?jk=50d5a5844e56e2...
#
#                   record.direct_link_to_the_job_page record.location  \
# 0                                                NaN             NaN
# 1  http://www.indeed.com/rc/clk?jk=c5d36d1df92067...             NaN
# 2  http://www.indeed.com/rc/clk?jk=eb4d64f6aee216...             NaN
# 3  http://www.indeed.com/rc/clk?jk=b0b80ca728afed...             NaN
# 4  http://www.indeed.com/rc/clk?jk=50d5a5844e56e2...             NaN
#
#              record.postedAt record.postedAtText record.sub_domain  \
# 0  2016-08-11 12:27:57 +0000          7 days ago        indeed.com
# 1  2016-08-01 12:27:57 +0000         17 days ago        indeed.com
# 2  2016-08-02 12:27:57 +0000         16 days ago        indeed.com
# 3  2016-08-04 12:27:57 +0000         14 days ago        indeed.com
# 4  2016-08-17 12:27:57 +0000           1 day ago        indeed.com
#
#                                         record.title  \
# 0                                   office assistant
# 1  Financial Investigators - Asset Forfeiture -El...
# 2               Provider Network Development Manager
# 3                      Supervisor, DSPO (El Paso TX)
# 4      Commercial Sales Estimator (Proposal Support)
#
#                      record.uniq_id
# 0  f458526241a5e46962bad2a97d8da5d3
# 1  d47b5ae26d622ddb898cda70325236db
# 2  e91c1b43c93e7d78d4ea8694e19c3e79
# 3  7b2c2fe8b0b241934465f53007c90944
# 4  9c864078cd298c8047a0e60e8ac63e3f

# %%
#load second json object
with open('D:/CAPSTONE_NEW/indeed_com-jobs_us_deduped_n_merged_20170817_113502269355122.json', encoding="utf-8-sig") as data_file:
    json_data2 = j.load(data_file)

# %%
#put data file 2 into a pandas df
#parent node is 'page'
#print first 5 rows
jobs_data2 = json_normalize(json_data2['page'])
jobs_data2.head(5)
# Out:
#                                              pageurl  \
# 0  http://www.indeed.com/viewjob?jk=3ff48bf17c8ba7d8
# 1  http://www.indeed.com/viewjob?jk=5a4065bc5279c2ed
# 2  http://www.indeed.com/viewjob?jk=36a5566bd1b6e2a9
# 3  http://www.indeed.com/company/Stat-Staff-Profe...
# 4  http://www.indeed.com/company/Walgreens/jobs/P...
#
#              record.company_name  \
# 0   United States Postal Service
# 1                 The Home Depot
# 2          UNITED PARCEL SERVICE
# 3  Stat Staff Professionals Inc.
# 4                      Walgreens
#
#                                   record.description  \
# 0  United States Postal Service\nExternal Publica...
# 1  Department Supervisors train, coach and develo...
# 2  UPS is accepting applications for temporary, s...
# 3  We're a staffing organization for RN's / Allie...
# 4  Assists in the control of extra shifts and ove...
#
#             record.direct_apply_link_on_the_job_page  \
# 0                                                NaN
# 1  http://www.indeed.com/rc/clk?jk=5a4065bc5279c2...
# 2  http://www.indeed.com/rc/clk?jk=36a5566bd1b6e2...
# 3                                                NaN
# 4                                                NaN
#
#                   record.direct_link_to_the_job_page record.location  \
# 0                                                NaN             NaN
# 1  http://www.indeed.com/rc/clk?jk=5a4065bc5279c2...             NaN
# 2  http://www.indeed.com/rc/clk?jk=36a5566bd1b6e2...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#              record.postedAt record.postedAtText record.sub_domain  \
# 0  2016-09-30 08:32:27 +0000          2 days ago        indeed.com
# 1  2016-09-02 08:32:27 +0000        30+ days ago        indeed.com
# 2  2016-09-22 08:32:27 +0000         10 days ago        indeed.com
# 3  2016-09-27 08:32:27 +0000          5 days ago        indeed.com
# 4  2016-09-02 08:32:27 +0000        30+ days ago        indeed.com
#
#                record.title                    record.uniq_id
# 0   HOLIDAY CLERK ASSISTANT  e21916b80e1a180d36acda730b3bb3c8
# 1     Department Supervisor  9080f8ba6a86029047743e1d7cf24e80
# 2   Package Delivery Driver  b6b9d20292d8f226a045ed0811f81685
# 3  CST / ST - Surgical Tech  c838ad0ea83d3bde3186a480da7b2ce5
# 4                Pharmacist  dc92c84e227efb05f48d240782ce7cab

# %%
#load second json object
with open('D:/CAPSTONE_NEW/indeed_com-jobs_us_deduped_n_merged_20170817_113515380318786.json', encoding="utf-8-sig") as data_file:
    json_data3 = j.load(data_file)

# %%
#put data file 3 into a pandas df
#parent node is 'page'
#print first 5 rows
jobs_data3 = json_normalize(json_data3['page'])
jobs_data3.head(5)
# Out:
#                                              pageurl  \
# 0  http://www.indeed.com/viewjob?jk=be7edbb74b6be0bb
# 1  http://www.indeed.com/viewjob?jk=67ff3f5c954799ca
# 2  http://www.indeed.com/cmp/Doss-Logistics-Inc./...
# 3  http://www.indeed.com/viewjob?jk=0485d12ddd522e15
# 4  http://www.indeed.com/viewjob?jk=72ce244fc23fc878
#
#                record.company_name  \
# 0                Hilton Garden Inn
# 1                          Onepath
# 2              Doss Logistics Inc.
# 3  Clovis Community Medical Center
# 4                   City of Fresno
#
#                                   record.description  \
# 0  Prepare ingredients for cooking, including por...
# 1  Job Description\nOnepath is seeking skilled lo...
# 2  Doss Logistics is hiring for a OTR Truck Drive...
# 3  Job Title: Infection Control Spec Fullt Time 8...
# 4  The City of Fresno is currently accepting appl...
#
#             record.direct_apply_link_on_the_job_page  \
# 0  http://www.indeed.com/rc/clk?jk=be7edbb74b6be0...
# 1  http://www.indeed.com/rc/clk?jk=67ff3f5c954799...
# 2                                                NaN
# 3  http://www.indeed.com/rc/clk?jk=0485d12ddd522e...
# 4  http://www.indeed.com/rc/clk?jk=72ce244fc23fc8...
#
#                   record.direct_link_to_the_job_page record.location  \
# 0  http://www.indeed.com/rc/clk?jk=be7edbb74b6be0...             NaN
# 1  http://www.indeed.com/rc/clk?jk=67ff3f5c954799...             NaN
# 2                                                NaN             NaN
# 3  http://www.indeed.com/rc/clk?jk=0485d12ddd522e...             NaN
# 4  http://www.indeed.com/rc/clk?jk=72ce244fc23fc8...             NaN
#
#              record.postedAt record.postedAtText record.sub_domain  \
# 0  2016-08-13 08:31:42 +0000        30+ days ago        indeed.com
# 1  2016-08-27 08:31:42 +0000         16 days ago        indeed.com
# 2  2016-09-03 08:31:42 +0000          9 days ago        indeed.com
# 3  2016-08-13 08:31:42 +0000        30+ days ago        indeed.com
# 4  2016-09-08 08:31:42 +0000          4 days ago        indeed.com
#
#                                     record.title  \
# 0                                   Banquet Cook
# 1                  Alarm Installation Technician
# 2          OTR Truck Driver (Home every weekend)
# 3  Infection Control Spec Fullt Time 8 Hour Days
# 4                         Industrial Electrician
#
#                      record.uniq_id
# 0  1e8651519814524b570a34c577b5e1a3
# 1  ea94198a6d1d55d6070dc941f17f1eba
# 2  bce1f30c1f041a2ecadec346831a3ecd
# 3  c382d4dc18ea3589a16b84861d47e483
# 4  046a4f5a8423554ae0aca69ff2cb91b9

# %%
#load second json object
with open('D:/CAPSTONE_NEW/indeed_com-jobs_us_deduped_n_merged_20170817_113529266152000.json', encoding="utf-8-sig") as data_file:
    json_data4 = j.load(data_file)

# %%
#put data file 4 into a pandas df
#parent node is 'page'
#print first 5 rows
jobs_data4 = json_normalize(json_data4['page'])
jobs_data4.head(5)
# Out:
#                                              pageurl  \
# 0  http://www.indeed.com/viewjob?jk=b4c7156c7d1cce8c
# 1  http://www.indeed.com/viewjob?jk=13612cef68d6fc1d
# 2  http://www.indeed.com/viewjob?jk=1969d1d3e19628cb
# 3  http://www.indeed.com/company/College-Chefs/jo...
# 4  http://www.indeed.com/viewjob?jk=dad38502b724b95a
#
#          record.company_name  \
# 0  Academy Sports + Outdoors
# 1                Wells Fargo
# 2               Interactions
# 3              College Chefs
# 4             Randall Reilly
#
#                                   record.description  \
# 0  Team Sports Sales Associate\n\nDescription\n\n...
# 1  Job Description\n\n\nAt Wells Fargo, our visio...
# 2  Provides a comprehensive event marketing strat...
# 3  Progressive, rapidly expanding company looking...
# 4  Our Sales Division is looking for a dynamic sa...
#
#             record.direct_apply_link_on_the_job_page  \
# 0  http://www.indeed.com/rc/clk?jk=b4c7156c7d1cce...
# 1  http://www.indeed.com/rc/clk?jk=13612cef68d6fc...
# 2  http://www.indeed.com/rc/clk?jk=1969d1d3e19628...
# 3                                                NaN
# 4  http://www.indeed.com/rc/clk?jk=dad38502b724b9...
#
#                   record.direct_link_to_the_job_page record.location  \
# 0  http://www.indeed.com/rc/clk?jk=b4c7156c7d1cce...  Tuscaloosa, AL
# 1  http://www.indeed.com/rc/clk?jk=13612cef68d6fc...      Forest, VA
# 2  http://www.indeed.com/rc/clk?jk=1969d1d3e19628...     Hanover, PA
# 3                                                NaN  Tuscaloosa, AL
# 4  http://www.indeed.com/rc/clk?jk=dad38502b724b9...  Tuscaloosa, AL
#
#              record.postedAt record.postedAtText record.sub_domain  \
# 0  2016-11-08 00:27:12 +0000        22 hours ago        indeed.com
# 1  2016-11-08 13:27:12 +0000         9 hours ago        indeed.com
# 2  2016-11-07 22:27:12 +0000           1 day ago        indeed.com
# 3  2016-10-09 22:27:12 +0000        30+ days ago        indeed.com
# 4  2016-11-08 16:27:12 +0000         6 hours ago        indeed.com
#
#                                         record.title  \
# 0                        Team Sports Sales Associate
# 1                                             TELLER
# 2  DI Special Services Sales Advisor - Hanover Ma...
# 3                                     Executive Chef
# 4                      Sales National Acct Executive
#
#                      record.uniq_id
# 0  33f7c38ef0c59b051085d693b0bcd4f3
# 1  77d8ec26352b981399b9cd87d2c7a194
# 2  ee9477f210efa6b2b38f2d6f05b62cff
# 3  c56653b7e5d6d0095cec262a02630053
# 4  344f7f7fd3e11c4a4968adda502e21b8

# %%
#merge jobs dataframes
full_data = pd.concat([jobs_data1, jobs_data2, jobs_data3, jobs_data4], ignore_index=True)

# %%
full_data.dtypes
# Out:
# pageurl                                     object
# record.company_name                         object
# record.description                          object
# record.direct_apply_link_on_the_job_page    object
# record.direct_link_to_the_job_page          object
# record.location                             object
# record.postedAt                             object
# record.postedAtText                         object
# record.sub_domain                           object
# record.title                                object
# record.uniq_id                              object
# dtype: object

# %%
#save clean dataframe to disk
full_data.to_pickle('D:/CAPSTONE_NEW/jobs_data_full.pkl')

# %% [markdown]
# # Step 2: Text Pre-Processing

# %%
#load pickled dataframe
jobs_data = pd.read_pickle('D:/CAPSTONE_NEW/jobs_data_full.pkl')

# %%
jobs_data.nunique()
# Out:
# pageurl                                     200444
# record.company_name                          44951
# record.description                          161355
# record.direct_apply_link_on_the_job_page    158999
# record.direct_link_to_the_job_page          158999
# record.location                              13371
# record.postedAt                              79704
# record.postedAtText                             81
# record.sub_domain                                1
# record.title                                113237
# record.uniq_id                              200444
# dtype: int64

# %%
#determine 50 most frequent job titles
freq_titles1 = jobs_data.groupby(['record.title']).size().reset_index(name='counts').sort_values('counts', ascending=False).head(50)
freq_titles1
# Out:
#                                             record.title  counts
# 68729                                 Physical Therapist     317
# 24229                    Customer Service Representative     247
# 3362                            Administrative Assistant     229
# 15732                                       Case Manager     224
# 73424                                    Project Manager     217
# 53322                             Maintenance Technician     196
# 42059                                        Help Wanted     185
# 24307  Customer Service Representative - State Farm A...     178
# 2163    Account Associate - State Farm Agent Team Member     175
# 60890                             Occupational Therapist     171
# 61588  Office Representative - State Farm Agent Team ...     170
# 41173                            Hair Stylist - Licensed     160
# 39155                                    General Manager     160
# 22290                                               Cook     160
# 6526                                   Assistant Manager     156
# 2494   Account Representative - State Farm Agent Team...     146
# 2382      Account Manager - State Farm Agent Team Member     142
# 46016  Insurance Account Representative - State Farm ...     134
# 46159  Insurance and Financial Services Position - St...     134
# 82765                                    Sales Associate     130
# 16769                        Certified Nursing Assistant     128
# 43659                            Human Resources Manager     126
# 84890                                   Security Officer     125
# 16781                  Certified Nursing Assistant (CNA)     125
# 56070                                  Medical Assistant     122
# 68353                                Pharmacy Technician     121
# 83315                               Sales Representative     118
# 90382                        Speech Language Pathologist     116
# 29884                                             Driver     105
# 48252                                                LPN     103
# 92960                                      Store Manager     102
# 33718                                 Executive Director     101
# 88166                                 Service Technician      99
# 62111                                 Operations Manager      96
# 55194  Marketing Representative - State Farm Agent Te...      95
# 87753                                             Server      94
# 9887                                           Bartender      92
# 92237                                   Staff Accountant      91
# 89114                                      Social Worker      91
# 26071                                   Dental Assistant      90
# 43628                         Human Resources Generalist      88
# 11839                                   Business Analyst      87
# 25824                                    Delivery Driver      84
# 67109                                 Payroll Specialist      83
# 2539                                          Accountant      82
# 13653                  CNA - Certified Nursing Assistant      81
# 9020                               Automotive Technician      80
# 33618                                Executive Assistant      80
# 68035                                         Pharmacist      79
# 83180                                      Sales Manager      79

# %%
jobs_data.tail()
# Out:
#                                                   pageurl  \
# 200439  http://www.indeed.com/viewjob?jk=eb30c82a2581c715
# 200440  http://www.indeed.com/viewjob?jk=ebb9dc956329c930
# 200441  http://www.indeed.com/viewjob?jk=1bcdaa85ff13fb43
# 200442  http://www.indeed.com/cmp/BENEDICT-COLLEGE/job...
# 200443  http://www.indeed.com/viewjob?jk=5b6643a9ede1ccc8
#
#                record.company_name  \
# 200439       SERG Restaurant Group
# 200440                    Michaels
# 200441  MedPro Healthcare Staffing
# 200442     ANGELO STATE UNIVERSITY
# 200443         Chenega Corporation
#
#                                        record.description  \
# 200439  Responsible for serving both alcoholic & non-a...
# 200440  Business Unit :\n\n\nMichaels Stores\n\n\nTitl...
# 200441  MedPro Healthcare Staffing, a Joint Commission...
# 200442  We are looking for several adjunct Instructors...
# 200443  The\n\nUnarmed Guard\n\nis primarily responsib...
#
#                  record.direct_apply_link_on_the_job_page  \
# 200439                                                NaN
# 200440  http://www.indeed.com/rc/clk?jk=ebb9dc956329c9...
# 200441                                                NaN
# 200442                                                NaN
# 200443  http://www.indeed.com/rc/clk?jk=5b6643a9ede1cc...
#
#                        record.direct_link_to_the_job_page record.location  \
# 200439                                                NaN             NaN
# 200440  http://www.indeed.com/rc/clk?jk=ebb9dc956329c9...             NaN
# 200441                                                NaN             NaN
# 200442                                                NaN             NaN
# 200443  http://www.indeed.com/rc/clk?jk=5b6643a9ede1cc...             NaN
#
#                   record.postedAt record.postedAtText record.sub_domain  \
# 200439  2016-08-14 14:43:52 +0000        30+ days ago        indeed.com
# 200440  2016-08-14 14:43:52 +0000        30+ days ago        indeed.com
# 200441  2016-08-14 14:43:52 +0000        30+ days ago        indeed.com
# 200442  2016-08-17 14:43:52 +0000         27 days ago        indeed.com
# 200443  2016-08-14 14:43:52 +0000        30+ days ago        indeed.com
#
#                                         record.title  \
# 200439  Cocktail Server - Poseidon & The Rooftop Bar
# 200440                            Department Manager
# 200441                     Travel Physical Therapist
# 200442           NEEDING PUBLIC SPEAKING INSTRUCTORS
# 200443                      Unarmed Guard USCIS (FT)
#
#                           record.uniq_id
# 200439  35284039646bd91580494441c918b1c1
# 200440  94351cf60f862b36adb6c1edc67089e9
# 200441  ed0dbad4ac8b8b382aeb28a308cacebc
# 200442  bb8f74edc980dc911b5c3b4c9b77494a
# 200443  6d05b1f7629b8f8683cb6a134f207605

# %%
#create word stemming object
stemmer = SnowballStemmer('english')
#create stop words object
s_words = stopwords.words('english')

# %%
#create clean role description data
#special character removal, stemming and stop word removal
#seperate new stemmed words with space only
jobs_data['clean_description'] = jobs_data['record.description'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", str(x)).split() if i not in s_words]).lower())

# %%
#print first 5 rows to show clean role description data
jobs_data['clean_description'].head(5)
# Out:
# 0    offic assistantrespons includ prepar sale orde...
# 1    financi investig asset forfeitur el paso asrc ...
# 2    employ summari summari job function purpos man...
# 3    profil job summari supervis train coach develo...
# 4    posit summari the nation account field support...
# Name: clean_description, dtype: object

# %%
#create clean job title data
#special character removal, stemming and stop word removal
#seperate new stemmed words with space only
jobs_data['clean_titles'] = jobs_data['record.title'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", str(x)).split() if i not in s_words]).lower())

# %%
#print first 5 rows to show clean job title data
jobs_data['clean_titles'].head(5)
# Out:
# 0                                offic assist
# 1    financi investig asset forfeitur el paso
# 2                provid network develop manag
# 3                  supervisor dspo el paso tx
# 4          commerci sale estim propos support
# Name: clean_titles, dtype: object

# %%
#count number of unique cases per column 
jobs_data.nunique()
#it is important to reduce the number of unique job titles
#unique job title count after text pre-processing has improved from 33898 out of 50295 (67%) to 32286 out of 50295 (64%)
#in comparison to job titles, all job descriptions should be unique to avoid a skew in tf-idf results
#only 42831 out of 50296 jobs are actually unique after cleaning, so duplicates must be removed by matching
# Out:
# pageurl                                     200444
# record.company_name                          44951
# record.description                          161355
# record.direct_apply_link_on_the_job_page    158999
# record.direct_link_to_the_job_page          158999
# record.location                              13371
# record.postedAt                              79704
# record.postedAtText                             81
# record.sub_domain                                1
# record.title                                113237
# record.uniq_id                              200444
# clean_description                           155880
# clean_titles                                105475
# dtype: int64

# %%
#remove duplicate job postings based on clean descriptions
jobs_data.drop_duplicates(subset='clean_description', keep='first', inplace=True)

# %%
#count number of unique cases per column 
jobs_data.nunique()
#there are now 42831 total job postings, where 7465 duplicates were removed
# Out:
# pageurl                                     155880
# record.company_name                          44279
# record.description                          155879
# record.direct_apply_link_on_the_job_page    118909
# record.direct_link_to_the_job_page          118909
# record.location                              11640
# record.postedAt                              68744
# record.postedAtText                             79
# record.sub_domain                                1
# record.title                                105060
# record.uniq_id                              155880
# clean_description                           155880
# clean_titles                                 98562
# dtype: int64

# %%
#remove duplicate job postings based on combination of same company name and same job title
jobs_data.drop_duplicates(subset=['record.company_name','clean_titles'], keep='first', inplace=True)

# %%
jobs_data.nunique()
#there are now 39464 total job postings, where 3367 duplicates were removed
# Out:
# pageurl                                     135826
# record.company_name                          44279
# record.description                          135825
# record.direct_apply_link_on_the_job_page    102574
# record.direct_link_to_the_job_page          102574
# record.location                              10634
# record.postedAt                              63077
# record.postedAtText                             79
# record.sub_domain                                1
# record.title                                103469
# record.uniq_id                              135826
# clean_description                           135826
# clean_titles                                 98562
# dtype: int64

# %%
#vectors of unhelpful double characters will be created, so we need to remove them
jobs_data['clean_description'].replace(to_replace=r"\s([a-z])\1+", value="", regex=True, inplace=True)

# %%
#there are a noticeable number of job titles with 'state farm agent team member'
#this text should be removed as it is branding that reduces number of cases per job title
jobs_data['clean_titles'].replace({' state farm agent team member':''}, regex=True, inplace=True)

# %%
jobs_data.nunique()
#there are now 39464 total job postings, where 3367 duplicates were removed
# Out:
# pageurl                                     135826
# record.company_name                          44279
# record.description                          135825
# record.direct_apply_link_on_the_job_page    102574
# record.direct_link_to_the_job_page          102574
# record.location                              10634
# record.postedAt                              63077
# record.postedAtText                             79
# record.sub_domain                                1
# record.title                                103469
# record.uniq_id                              135826
# clean_description                           135825
# clean_titles                                 98542
# dtype: int64

# %%
#save clean dataframe to disk and free memory
jobs_data.to_pickle('D:/CAPSTONE_NEW/jobs_data_clean.pkl')
import gc
gc.collect()
# Out:
# 7

# %% [markdown]
# # Step 3: Text Mining

# %%
#load pickled dataframe
final_data = pd.read_pickle('D:/CAPSTONE_NEW/jobs_data_clean.pkl')

# %%
#determine 200 most frequent job titles for use as predictors, counts by job title are n=30 or more
#this is because kmeans clustering is not effective as dimensional reduction due to all of the noisy text
freq_titles = final_data.groupby(['clean_titles']).size().reset_index(name='counts').sort_values('counts', ascending=False).head(200)
freq_titles
# Out:
#                      clean_titles  counts
# 22242        custom servic repres     442
# 64501            physic therapist     331
# 533                 account manag     293
# 1498             administr assist     261
# 12182                  case manag     245
# 69250               project manag     232
# 49818          mainten technician     210
# 301                account associ     190
# 38772                   help want     186
# 19888                        cook     181
# 57443             occup therapist     181
# 58091                offic repres     178
# 36442               general manag     165
# 5108                 assist manag     163
# 13696     certifi nurs assist cna     162
# 840                account repres     160
# 37818         hair stylist licens     160
# 40779         human resourc manag     155
# 77520                 sale associ     147
# 79847                 secur offic     140
# 13681         certifi nurs assist     137
# 42757  insur financi servic posit     134
# 42688        insur account repres     134
# 85603  speech languag pathologist     133
# 63877         pharmaci technician     132
# 52562                medic assist     129
# 78143                 sale repres     126
# 71858                receptionist     118
# 27544                      driver     117
# 88336                 store manag     108
# ...                           ...     ...
# 68684            program director      32
# 32406    famili practic physician      32
# 34592          food servic worker      32
# 35080            front desk agent      32
# 10923         busi system analyst      32
# 33327                financ manag      32
# 90958                   tax manag      31
# 74859       restaur general manag      31
# 68542              program assist      31
# 5754               assist teacher      31
# 76049               rn case manag      31
# 79795                 secur guard      31
# 4532          assist branch manag      31
# 4839         assist director nurs      31
# 78977         school psychologist      31
# 36379               general labor      31
# 84565             softwar develop      31
# 86024            speech therapist      31
# 77745                sale consult      31
# 48009              loan processor      30
# 7569    automot servic technician      30
# 55003      mortgag loan processor      30
# 40848    human resourc specialist      30
# 22940              data scientist      30
# 56354               night auditor      30
# 18520             communiti manag      30
# 31260                 execut chef      30
# 11368          call center repres      30
# 57750         occup therapist prn      30
# 30715                  equip oper      30
#
# [200 rows x 2 columns]

# %%
#remove all cases from dataframe except those with top 200 job titles 
final_data = final_data[jobs_data['clean_titles'].isin(freq_titles['clean_titles'])]
final_data.nunique()
#there are now 4318 unique total job postings, where 35146 were removed that had same job title counts of n<10
# Out:
# pageurl                                     14148
# record.company_name                         10538
# record.description                          14148
# record.direct_apply_link_on_the_job_page     9357
# record.direct_link_to_the_job_page           9357
# record.location                              3653
# record.postedAt                             11766
# record.postedAtText                            61
# record.sub_domain                               1
# record.title                                  796
# record.uniq_id                              14148
# clean_description                           14148
# clean_titles                                  200
# dtype: int64

# %%
#generate numerical category labels for job titles to be used during classification
final_data["clean_titles_cat"] = final_data["clean_titles"].astype('category').cat.codes
final_data.head()
# Out:
#                                               pageurl  \
# 0   http://www.indeed.com/cmp/Tileland-Interior-De...
# 5   http://www.indeed.com/viewjob?jk=b02626aaeaa5b670
# 6   http://www.indeed.com/cmp/Network-Medical-Mana...
# 9   http://www.indeed.com/viewjob?jk=74b4486fba962240
# 12  http://www.indeed.com/viewjob?jk=210f7df8479839f1
#
#             record.company_name  \
# 0   Tileland Interior Decor LLC
# 5      Franchise: Audi Pasadena
# 6    Network Medical Management
# 9           KIK Custom Products
# 12             CST Brands, Inc.
#
#                                    record.description  \
# 0   Office assistantResponsibilities include: Prep...
# 5   Sales Consultant\n\n\nThis position contribute...
# 6   SUMMARYDirectly responsible for coordinating a...
# 9   COMPANY:\n\nAs one of North America’s largest ...
# 12  WE ARE THE CORNERSTORE!\n\n\nWe are recruiting...
#
#              record.direct_apply_link_on_the_job_page  \
# 0                                                 NaN
# 5   http://www.indeed.com/rc/clk?jk=b02626aaeaa5b6...
# 6                                                 NaN
# 9   http://www.indeed.com/rc/clk?jk=74b4486fba9622...
# 12  http://www.indeed.com/rc/clk?jk=210f7df8479839...
#
#                    record.direct_link_to_the_job_page record.location  \
# 0                                                 NaN             NaN
# 5   http://www.indeed.com/rc/clk?jk=b02626aaeaa5b6...             NaN
# 6                                                 NaN             NaN
# 9   http://www.indeed.com/rc/clk?jk=74b4486fba9622...             NaN
# 12  http://www.indeed.com/rc/clk?jk=210f7df8479839...             NaN
#
#               record.postedAt record.postedAtText record.sub_domain  \
# 0   2016-08-11 12:27:57 +0000          7 days ago        indeed.com
# 5   2016-08-12 12:27:57 +0000          6 days ago        indeed.com
# 6   2016-08-10 12:27:57 +0000          8 days ago        indeed.com
# 9   2016-07-22 12:27:57 +0000         27 days ago        indeed.com
# 12  2016-07-25 12:27:57 +0000         24 days ago        indeed.com
#
#                   record.title                    record.uniq_id  \
# 0             office assistant  f458526241a5e46962bad2a97d8da5d3
# 5             Sales Consultant  63c2ebf15b716afdea9598fd8833eb97
# 6    Human Resources Assistant  98daf5ad5ded0346d76d43068d0118e3
# 9   Human Resources Generalist  e71d38c8cddc483737d077bb10e778c4
# 12               Store Manager  16e23c7845fdfce13680d64a8f38a645
#
#                                     clean_description  \
# 0   offic assistantrespons includ prepar sale orde...
# 5   sale consult this posit contribut success rusn...
# 6   summarydirect respons coordin aspect locat via...
# 9   compani as one north america largest independ ...
# 12  we are the cornerstor we recruit store manag n...
#
#                 clean_titles  clean_titles_cat
# 0               offic assist               121
# 5               sale consult               166
# 6       human resourc assist                78
# 9   human resourc generalist                80
# 12               store manag               188

# %%
#create tokenized job descriptions as independent features for classification
#(unigrams and bigrams) from words with more than 1 letter in clean job descriptions
#print first 20 feature names
vectorizer = TfidfVectorizer(token_pattern=r'\w{2,}', ngram_range=(1,2), stop_words='english', sublinear_tf=True)
desc_matrix = vectorizer.fit_transform(final_data['clean_description'])
feature_names = vectorizer.get_feature_names()
print(feature_names[:20])
# Out:
# ['aaa', 'aaa car', 'aaa northeast', 'aacr', 'aacr wac', 'aamco', 'aamco transmiss', 'aaron', 'aaron provid', 'aaski', 'aaski technolog', 'ab', 'ab ac', 'ab ae', 'ab brake', 'ab car', 'ab function', 'ab maximimum', 'ab maximum', 'ab pay']

# %%
#display the total number of features produced for job descriptions
len(feature_names)
# Out:
# 808932

# %%
#display top 100 features from job descriptions based on Tf-Idf scores
indices = np.argsort(vectorizer.idf_)[::-1]
top_n = 100
top_features = [feature_names[i] for i in indices[:top_n]]
print(top_features)
# Out:
# ['zynex suit', 'hns organ', 'hns mission', 'hns manag', 'hns', 'hne bod', 'hne', 'hnbhs regulatori', 'hnbhs facilit', 'hnbhs', 'hna fleet', 'hna dress', 'hna', 'hn summari', 'hn hs', 'hmw high', 'hmw', 'hns nurs', 'hns perform', 'hmso', 'hns polici', 'hoa fine', 'hoa duti', 'hoa certif', 'hoa build', 'ho mental', 'ho cultur', 'hntb team', 'hntb servic', 'hntb presenc', 'hntb local', 'hntb current', 'hntb cultur', 'hntb corpor', 'hntb', 'hns support', 'hmso revis', 'hmsnm org', 'hoa notic', 'hmo ncqa', 'hmo manag', 'hmo dental', 'hmo case', 'hmis program', 'hmis increas', 'hmis dhmh', 'hmis client', 'hmis catch', 'hmis basic', 'hmi robot', 'hmi program', 'hmi logix', 'hmi laboratori', 'hmi graphic', 'hmi experi', 'hmo mco', 'hmo option', 'hmsnm', 'hmo plan', 'hms support', 'hms provid', 'hms profit', 'hms polici', 'hms offer', 'hms non', 'hms feder', 'hms competit', 'hmrc partner', 'hmrc', 'hmoo tpa', 'hmoo medicar', 'hmoo health', 'hmoo dental', 'hmo requir', 'hoa manag', 'hoa prior', 'hmhco com', 'hoi posit', 'hoh result', 'hoh', 'hog hollow', 'hog', 'hoffman southwest', 'hoffman mccann', 'hoffman estat', 'hoe track', 'hoe rake', 'hoe haul', 'hode categori', 'hode', 'hockey knit', 'hockey activ', 'hoc user', 'hoi', 'hoist equip', 'hoc summari', 'hoist exclus', 'hol', 'hoku rd', 'hoku offer']

# %%
#save final new dataframe to disk and free memory
final_data.to_pickle('D:/CAPSTONE_NEW/jobs_data_final.pkl')
gc.collect()
# Out:
# 98

# %% [markdown]
# # Step 4: Text Classification

# %%
#load pickled dataframe
model_data = pd.read_pickle('D:/CAPSTONE_NEW/jobs_data_final.pkl')

# %%
#create classifier object with train and test data sets
#include assessment tests within object
#job skills as independent variable and job titles as dependent variable

def train(classifier, X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=33)

    classifier.fit(X_train, y_train)
    print('Initial Model Accuracy: %s' % classifier.score(X_test, y_test))
   
    predicted = classifier.predict(X_test)
    precision, recall, fscore, support = precision_recall_fscore_support(y_test, predicted, average='weighted')
    print('Precision: {}'.format(precision))
    print('Recall: {}'.format(recall))
    print('F-score: {}'.format(fscore))
    print('Support: {}'.format(support))

    return classifier

# %%
#run classification using NaiveBayes
clf1 = Pipeline([
    ('vectorizer', TfidfVectorizer(token_pattern=r'\w{2,}', ngram_range=(1,2), stop_words='english', sublinear_tf=True)),
    ('classifier', MultinomialNB(alpha=0.05)),
])
 
nb_model = train(clf1, model_data['clean_description'], model_data['clean_titles_cat'])
#produces extremely poor accuracy
# Out:
# Initial Model Accuracy: 0.27043580683156654
# Precision: 0.38250341153014505
# Recall: 0.27043580683156654
# F-score: 0.21984668507027957
# Support: None
# D:\anaconda\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#run classification using RandomForests
clf2 = Pipeline([
    ('vectorizer', TfidfVectorizer(token_pattern=r'\w{2,}', ngram_range=(1,2), stop_words='english', sublinear_tf=True)),
    ('classifier', RandomForestClassifier()),
])
 
rf_model = train(clf2, model_data['clean_description'], model_data['clean_titles_cat'])
#produces poor accuracy
# Out:
# Initial Model Accuracy: 0.3491166077738516
# Precision: 0.38404365554211395
# Recall: 0.3491166077738516
# F-score: 0.3302604970853345
# Support: None
# D:\anaconda\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#run classification using SVM
clf3 = Pipeline([
    ('vectorizer', TfidfVectorizer(token_pattern=r'\w{2,}', ngram_range=(1,2), stop_words='english', sublinear_tf=True)),
    ('classifier', LinearSVC(C=1.0, penalty='l1', max_iter=1000, dual=False)),
])
 
svm_model = train(clf3, model_data['clean_description'], model_data['clean_titles_cat'])
#produces good accuracy
# Out:
# Initial Model Accuracy: 0.6713780918727915
# Precision: 0.6975553576659304
# Recall: 0.6713780918727915
# F-score: 0.6594118359383865
# Support: None
# D:\anaconda\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
